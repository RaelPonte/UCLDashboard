# %%
from duckdb_controller import DuckDBController
from data_ingestion import DataIngestion
import glob
from duckdb import CatalogException

data_ingestion = DataIngestion()

csv_files_path = glob.glob("../data/*.csv")
print("CSV Files:", csv_files_path)
for path in csv_files_path:
    table_name = path.split("/")[-1].replace(".csv", "")
    print(data_ingestion.ingest_data(table_name, path))

# %%
duckdb.select_all_from_table(table_name='attempts')
# Out:
# Selecting all from table attempts...
#     serial  player_name         club    position  total_attempts  on_target  \
# 0       01      Benzema  Real Madrid     Forward              45         23
# 1       02        Salah    Liverpool     Forward              42         22
# 2       03       Mahrez    Man. City  Midfielder              37         18
# 3       04         Sané       Bayern  Midfielder              33         13
# 4       05  Lewandowski       Bayern     Forward              31         19
# ..     ...          ...          ...         ...             ...        ...
# 541    440  Dina Ebimbe        Paris  Midfielder               1          0
# 542    440     N'Koudou     Beşiktaş  Midfielder               1          0
# 543    440    Izquierdo  Club Brugge     Forward               1          0
# 544    440     Radonjić      Benfica     Forward               1          0
# 545    440       Agüero    Barcelona     Forward               1          0
#
# ...
